# %% [markdown]
# # 平日と休日の釣果比較

# %%
# モジュールのインポート

import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
import datetime
import jpholiday
import sqlite3
import seaborn as sns

# グラフサイズ変更。既定より大きくする

plt.rcParams['figure.figsize'] = [10, 6]

# seaborn グラフにグリッド線を追加

sns.set()
sns.set_style("whitegrid", {'grid.linestyle': '--'})

# %%
# 大黒海釣り施設の2018年以降の釣果検索

conn = sqlite3.connect("../data/fishing_result.db")
sql = '''
select
    r.Date,
    r.Species,
    r.Point,
    r.Count,
    r.SizeMin,
    r.SizeMax,
    c.WaterTemp,
    c.Quantity
from
    fishing_results r,
    fishing_comments c
where
    r.Date = c.Date
    and r.Point = c.Point
    and r.Point = 'daikoku'
    and r.Date > '2011-01-01'
'''
df=pd.read_sql_query(sql, conn)
df.head()
# Out:
#          Date Species    Point  Count  SizeMin  SizeMax  WaterTemp  Quantity
# 0  2011-04-27      アジ  daikoku    1.0     26.0     26.0        NaN       NaN
# 1  2011-04-27     カサゴ  daikoku    1.0     15.0     15.0        NaN       NaN
# 2  2011-04-27     スズキ  daikoku    2.0     55.0     62.0        NaN       NaN
# 3  2011-04-27      ソイ  daikoku    1.0     20.0     20.0        NaN       NaN
# 4  2011-04-27      ハゼ  daikoku    1.0     10.0     10.0        NaN       NaN

# %%
# 土日祝日化判定列を追加

df['Date'] = pd.to_datetime(df.Date)
def isBizDay(Date):
    if Date.weekday() >= 5 or jpholiday.is_holiday(Date):
        return 'Holiday'
    else:
        return 'WeekDay'

df['BizDay'] = df.apply(lambda x: isBizDay(x.Date), axis=1)

# 日付を索引にセットし、年、月カラムを追加

df = df.set_index('Date')
df['Year'] = df.index.year
df['Month'] = df.index.month
df['DayOfYear'] = df.index.dayofyear
df['WeekOfYear'] = df.index.strftime('%U').astype(int) # df3.index.week

# %%
# 日本語の文字化け対策のため、主要な魚種をローマ字に変換

def get_spieces_alphabet(spieces):
    if spieces == 'アジ':
        return 'Aji'
    elif spieces == 'クロダイ':
        return 'Kurodai'
    elif spieces == 'メジナ':
        return 'Mejina'
    elif spieces == 'メバル':
        return 'Mebaru'
    elif spieces == 'カサゴ':
        return 'Kasago'
    else:
        return 'Etc'

df['Species'] = df.apply(lambda x: get_spieces_alphabet(x.Species), axis=1)

df.head()
# Out:
#            Species    Point  Count  SizeMin  SizeMax  WaterTemp  Quantity  \
# Date
# 2011-04-27     Aji  daikoku    1.0     26.0     26.0        NaN       NaN
# 2011-04-27  Kasago  daikoku    1.0     15.0     15.0        NaN       NaN
# 2011-04-27     Etc  daikoku    2.0     55.0     62.0        NaN       NaN
# 2011-04-27     Etc  daikoku    1.0     20.0     20.0        NaN       NaN
# 2011-04-27     Etc  daikoku    1.0     10.0     10.0        NaN       NaN
#
#              BizDay  Year  Month  DayOfYear  WeekOfYear
# Date
# 2011-04-27  WeekDay  2011      4        117          17
# 2011-04-27  WeekDay  2011      4        117          17
# 2011-04-27  WeekDay  2011      4        117          17
# 2011-04-27  WeekDay  2011      4        117          17
# 2011-04-27  WeekDay  2011      4        117          17

# %% [markdown]
# # 魚種別釣果数の違い

# %%
# アジ、その他の魚種の釣果を取り除く

df3 = df.query('Species != "Etc" and Species != "Aji"')

# 平日、休日の違い、魚種別釣果数

sns.boxplot(data=df3, x='Species', y='Count', hue='BizDay')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Count'>

# %%
# 平日、休日の違い、魚種別釣果サイズ

sns.boxplot(data=df3, x='Species', y='SizeMax', hue='BizDay')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SizeMax'>

# %%
# 魚種別釣果サイズの推移
plt.rcParams['figure.figsize'] = [8, 10]
sns.relplot(data=df.query('Species!="Etc"'), x='Month', y='SizeMax', hue='Species', col='Year', kind='line',col_wrap=6)

# %%
sns.lineplot(data=df.query('Species!="Etc"'), x='Year', y='SizeMax', hue='Species')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='SizeMax'>

# %%
# アジの釣果のみ釣果数

df2 = df.query('Species == "Aji"')
sns.boxplot(data=df2, x='Year', y='Count', hue='BizDay')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Count'>

# %%
sns.boxplot(data=df2, x='Year', y='SizeMax', hue='BizDay')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='SizeMax'>

# %%
sns.violinplot(data = df2, x="Year", y="SizeMax", hue="BizDay", split=True, inner="quart")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='SizeMax'>

# %%
sns.boxplot(data=df2, x='Month', y='SizeMax', hue='BizDay')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='SizeMax'>

# %%
sns.relplot(data=df2, x='Month', y='SizeMax', col='Year', hue='BizDay', kind='line', col_wrap=4)

# %%
sns.lineplot(data=df, x='Month', y='WaterTemp', hue='Year')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='WaterTemp'>

# %%
sns.relplot(data=df, x='Month', y='WaterTemp', col='Year', col_wrap=4)
